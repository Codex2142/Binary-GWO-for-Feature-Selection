# %% [markdown]
# # Import Lib

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from ucimlrepo import fetch_ucirepo

# %% [markdown]
# # Download dataset

# %%
# fetch dataset 
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17) 
  
# data (as pandas dataframes) 
X = breast_cancer_wisconsin_diagnostic.data.features 
y = breast_cancer_wisconsin_diagnostic.data.targets

# %% [markdown]
# # Merge fitur dan target

# %%
df = pd.concat([X, y], axis=1)

# %% [markdown]
# # split data

# %%
train_val, test = train_test_split(
    df,
    test_size=114,
    stratify=df["Diagnosis"],
)

# %%
train_val.count()
# Out:
# radius1               455
# texture1              455
# perimeter1            455
# area1                 455
# smoothness1           455
# compactness1          455
# concavity1            455
# concave_points1       455
# symmetry1             455
# fractal_dimension1    455
# radius2               455
# texture2              455
# perimeter2            455
# area2                 455
# smoothness2           455
# compactness2          455
# concavity2            455
# concave_points2       455
# symmetry2             455
# fractal_dimension2    455
# radius3               455
# texture3              455
# perimeter3            455
# area3                 455
# smoothness3           455
# compactness3          455
# concavity3            455
# concave_points3       455
# symmetry3             455
# fractal_dimension3    455
# Diagnosis             455
# dtype: int64

# %%
test.count()
# Out:
# radius1               114
# texture1              114
# perimeter1            114
# area1                 114
# smoothness1           114
# compactness1          114
# concavity1            114
# concave_points1       114
# symmetry1             114
# fractal_dimension1    114
# radius2               114
# texture2              114
# perimeter2            114
# area2                 114
# smoothness2           114
# compactness2          114
# concavity2            114
# concave_points2       114
# symmetry2             114
# fractal_dimension2    114
# radius3               114
# texture3              114
# perimeter3            114
# area3                 114
# smoothness3           114
# compactness3          114
# concavity3            114
# concave_points3       114
# symmetry3             114
# fractal_dimension3    114
# Diagnosis             114
# dtype: int64

# %% [markdown]
# # Export dataset

# %%
train_val.to_csv("../dataset/train_val.data", index=False)
test.to_csv("../dataset/test.data", index=False)
